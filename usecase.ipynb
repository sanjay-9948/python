# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjay-9948/python/blob/main/usecase.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

outcomes = ["Heads", "Tails"]
probabilities = [0.5, 0.5]

plt.bar(outcomes, probabilities, color='lightgreen', edgecolor='black')
plt.title("Probability Distribution of a Coin Toss")
plt.ylabel("Probability")

# Properly indented loop
for i, prob in enumerate(probabilities):
    plt.text(i, prob + 0.02, str(prob), ha='center')

plt.show()
